# %%
import pandas as pd
import numpy as np
#need an 18x3 table
thread_list = np.array([128, 64, 32, 16, 4, 2, 32, 32, 32, 32, 32, 32, 16, 64, 128, 8, 4, 2])
prefetch_list = np.array([8, 8, 8, 8, 8, 8, 2, 4, 16, 32, 64, 128, 16, 64, 128, 8, 4, 2])
mean_list = np.array([964.84, 999.59, 1082.30, 1064.02, 984.60, 509.48, 670.35, 826.62, 1080.65, 1089.25, 1070.41, 1036.68, 1135.24, 925.04, 831.2, 1022.18, 611.60, 360.13])

d = {'Number of Parallel Threads':thread_list, 'Prefetch Buffer Size': prefetch_list, 'Mean Image Rate': mean_list}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#     Number of Parallel Threads  Prefetch Buffer Size  Mean Image Rate
# 0                          128                     8           964.84
# 1                           64                     8           999.59
# 2                           32                     8          1082.30
# 3                           16                     8          1064.02
# 4                            4                     8           984.60
# 5                            2                     8           509.48
# 6                           32                     2           670.35
# 7                           32                     4           826.62
# 8                           32                    16          1080.65
# 9                           32                    32          1089.25
# 10                          32                    64          1070.41
# 11                          32                   128          1036.68
# ...

# %% [markdown]
# The best run was with parallel_threads = 16, prefetch_buffer_size = 16, for a mean image rate of 1135.24.
